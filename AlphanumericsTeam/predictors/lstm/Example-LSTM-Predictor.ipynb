# %% [raw]
# # Copyright 2020 (c) Cognizant Digital Business, Evolutionary AI. All rights reserved. Issued under the Apache 2.0 License.

# %%
import os
import pandas as pd
import requests 
from AlphanumericsTeam.data.util import get_aug_oxford_df, filter_df_regions


REPO_ROOT = os.path.abspath(os.path.join(os.path.abspath(''), os.pardir, os.pardir, os.pardir))

# %%
#sample input and output

# IP until 30 sep
EXAMPLE_INPUT_FILE = os.path.join(REPO_ROOT, "covid_xprize/validation/data/2020-09-30_historical_ip.csv")
prediction_input_df = pd.read_csv(EXAMPLE_INPUT_FILE,
                                  parse_dates=['Date'],
                                  dtype={"RegionName": str},
                                  encoding="ISO-8859-1")

#print(prediction_input_df)

#prediction from Aug 1 to Aug 4
EXAMPLE_OUTPUT_FILE = os.path.join(REPO_ROOT, "2020-08-01_2020-08-04_predictions_example.csv")
prediction_output_df = pd.read_csv(EXAMPLE_OUTPUT_FILE,
                                   parse_dates=['Date'],
                                   encoding="ISO-8859-1")  


print(prediction_output_df)

# %%
# Input data for training

#DATA_URL = 'https://raw.githubusercontent.com/OxCGRT/covid-policy-tracker/master/data/OxCGRT_latest.csv'
#df = pd.read_csv(DATA_URL,
#                 parse_dates=['Date'],
#                 encoding="ISO-8859-1",
#                 dtype={"RegionName": str,
#                        "RegionCode": str},
#                 error_bad_lines=False)

# Has 6 additional columns 
# 'New Cases' 
# 'GeoID' 
# 'Holidays' 
# 'pop_2020' 
# 'area_km2' 
# 'density_perkm2'
df = get_aug_oxford_df() 
df = filter_df_regions(df)

# Final list of 180 countries and 56 regions
assert df.CountryName.unique().size == 180
assert df.RegionName.unique().size == 56 + 1

# %%
df.sample(3)
df["DailyChangeConfirmedCases"] = df.groupby(["CountryName", "RegionName"]).ConfirmedCases.diff().fillna(0)
california_df = df[(df.CountryName == "United States") & (df.RegionName == "California")]
california_df[["CountryName", "RegionName", "Date", "ConfirmedCases", "DailyChangeConfirmedCases"]].tail(5)

# %%
# TRAINING
import xprize_predictor
from importlib import reload
reload(xprize_predictor)
from xprize_predictor import XPrizePredictor

DATA_PATH = os.path.join("data", 'OxCGRT_latest_aug.csv')
predictor = XPrizePredictor(None, DATA_PATH)
 
predictor_model = predictor.train()

model_weights_file = "models/trained_model_weights.h5"
if not os.path.exists('models'):
    os.mkdir('models')
predictor_model.save_weights(model_weights_file)
# Out:
# Creating numpy arrays for Keras for each country...
# Numpy arrays created
# array([0.95724853, 1.03381305, 1.03184819, ..., 1.00001225, 1.00001225,
#        1.00001225])
# Trial 0
# Epoch 1/100
# 29/29 [==============================] - 2s 68ms/step - loss: 1.0197 - val_loss: 1.0236
# Epoch 2/100
# 29/29 [==============================] - 1s 51ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 3/100
# 29/29 [==============================] - 1s 50ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 4/100
# 29/29 [==============================] - 1s 51ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 5/100
# 29/29 [==============================] - 1s 51ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 6/100
# 29/29 [==============================] - 1s 51ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 7/100
# 29/29 [==============================] - 1s 52ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 8/100
# 29/29 [==============================] - 1s 51ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 9/100
# 29/29 [==============================] - 1s 52ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 10/100
# 29/29 [==============================] - 1s 51ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 11/100
# 29/29 [==============================] - 1s 50ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 12/100
# 29/29 [==============================] - 1s 50ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 13/100
# 29/29 [==============================] - 1s 51ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 14/100
# 29/29 [==============================] - 1s 50ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 15/100
# 29/29 [==============================] - 1s 51ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 16/100
# 29/29 [==============================] - 1s 50ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 17/100
# 29/29 [==============================] - 1s 51ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 18/100
# 29/29 [==============================] - 1s 50ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 19/100
# 29/29 [==============================] - 1s 51ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 20/100
# 29/29 [==============================] - 1s 51ms/step - loss: 1.0315 - val_loss: 1.0236
# Epoch 21/100
# 29/29 [==============================] - 1s 50ms/step - loss: 1.0315 - val_loss: 1.0236
# 252/252 [==============================] - 2s 9ms/step - loss: 1.0307
# Train Loss: 1.0196583271026611
# Val Loss: 1.023604393005371
# Test Loss: 1.0307368040084839
# ############ [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fce56554d10>, <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fce56542790>, <tensorflow.python.keras.layers.recurrent_v2.LSTM object at 0x7fce56537b10>, <tensorflow.python.keras.layers.recurrent_v2.LSTM object at 0x7fcd7a03d490>, <tensorflow.python.keras.layers.core.Dense object at 0x7fce56591b50>, <tensorflow.python.keras.layers.core.Dense object at 0x7fcdc2323b10>, <tensorflow.python.keras.layers.core.Lambda object at 0x7fcd7a0420d0>] 1
# Done
# {'Afghanistan': 38325227.0,
#  'Albania': 39588762.0,
#  'Algeria': 37259497.0,
#  'Andorra': 40437904.0,
#  'Angola': 40179190.0,
#  'Argentina': 19796367.0,
#  'Aruba': 40451002.0,
#  'Australia': 39818344.0,
#  'Austria': 34180340.0,
#  'Azerbaijan': 37869935.0,
#  'Bahamas': 40377922.0,
#  'Bahrain': 40224945.0,
#  'Bangladesh': 32314563.0,
#  'Barbados': 40460907.0,
#  'Belarus': 39035214.0,
#  'Belgium': 25162541.0,
#  'Belize': 40299303.0,
#  'Benin': 40451486.0,
#  'Bermuda': 40460443.0,
#  'Bhutan': 40462264.0,
#  'Bolivia': 30764207.0,
#  'Bosnia and Herzegovina': 35783019.0,
#  'Botswana': 40458466.0,
#  'Brazil': 10511602.0,
#  'Brunei': 40461408.0,
#  'Bulgaria': 33026242.0,
#  'Burkina Faso': 40442088.0,
#  'Burundi': 40461581.0,
#  'Cambodia': 40461794.0,
#  'Cameroon': 40061817.0,
#  'Canada': 28800478.0,
#  'Cape Verde': 40413144.0,
#  'Central African Republic': 40446088.0,
#  'Chad': 40417886.0,
#  'Chile': 28173682.0,
#  'China': 35123350.0,
#  'Colombia': 20231113.0,
#  'Comoros': 40461028.0,
#  'Congo': 40410392.0,
#  'Costa Rica': 38375149.0,
#  "Cote d'Ivoire": 40391210.0,
#  'Croatia': 36436348.0,
#  'Cuba': 40389960.0,
#  'Cyprus': 40431327.0,
#  'Czech Republic': 30400620.0,
#  'Democratic Republic of Congo': 40188023.0,
#  'Denmark': 39679095.0,
#  'Djibouti': 40446616.0,
#  'Dominica': 40462302.0,
#  'Dominican Republic': 37652141.0,
#  'Ecuador': 28837613.0,
#  'Egypt': 32333100.0,
#  'El Salvador': 39217270.0,
#  'Eritrea': 40462138.0,
#  'Estonia': 40343989.0,
#  'Eswatini': 40386653.0,
#  'Ethiopia': 38398914.0,
#  'Faeroe Islands': 40461705.0,
#  'Fiji': 40461593.0,
#  'Finland': 40030623.0,
#  'France': 16151060.0,
#  'Gabon': 40446018.0,
#  'Gambia': 40396260.0,
#  'Georgia': 38279834.0,
#  'Germany': 21663313.0,
#  'Ghana': 40230775.0,
#  'Greece': 35667699.0,
#  'Greenland': 40461601.0,
#  'Guam': 40398781.0,
#  'Guatemala': 34994006.0,
#  'Guinea': 40439287.0,
#  'Guyana': 40380309.0,
#  'Haiti': 40290068.0,
#  'Honduras': 36703900.0,
#  'Hong Kong': 40394117.0,
#  'Hungary': 31068530.0,
#  'Iceland': 40459879.0,
#  'India': 12357405.0,
#  'Indonesia': 24976648.0,
#  'Iran': 17563797.0,
#  'Iraq': 29302353.0,
#  'Ireland': 38111099.0,
#  'Israel': 36684922.0,
#  'Italy': 14008647.0,
#  'Jamaica': 40250555.0,
#  'Japan': 36803031.0,
#  'Jordan': 35984601.0,
#  'Kazakhstan': 37301696.0,
#  'Kenya': 38565955.0,
#  'Kosovo': 39207513.0,
#  'Kuwait': 39817726.0,
#  'Kyrgyz Republic': 38764377.0,
#  'Laos': 40461723.0,
#  'Latvia': 40087016.0,
#  'Lebanon': 39177672.0,
#  'Lesotho': 40450345.0,
#  'Liberia': 40435127.0,
#  'Libya': 38900931.0,
#  'Lithuania': 39777863.0,
#  'Luxembourg': 40058071.0,
#  'Macao': 40461705.0,
#  'Madagascar': 40261282.0,
#  'Malawi': 40299573.0,
#  'Malaysia': 40149838.0,
#  'Mali': 40292735.0,
#  'Mauritania': 40255418.0,
#  'Mauritius': 40460115.0,
#  'Mexico': 12753928.0,
#  'Moldova': 36966766.0,
#  'Monaco': 40461404.0,
#  'Mongolia': 40462959.0,
#  'Morocco': 32628099.0,
#  'Mozambique': 40385016.0,
#  'Myanmar': 37365273.0,
#  'Namibia': 40376871.0,
#  'Nepal': 38479861.0,
#  'Netherlands': 30114741.0,
#  'New Zealand': 40460037.0,
#  'Nicaragua': 40378346.0,
#  'Niger': 40434774.0,
#  'Nigeria': 39278169.0,
#  'Norway': 40173539.0,
#  'Oman': 38776574.0,
#  'Pakistan': 30755655.0,
#  'Palestine': 39371812.0,
#  'Panama': 36064303.0,
#  'Papua New Guinea': 40460615.0,
#  'Paraguay': 38316715.0,
#  'Peru': 20326127.0,
#  'Philippines': 30842599.0,
#  'Poland': 23120588.0,
#  'Portugal': 33465076.0,
#  'Puerto Rico': 38820026.0,
#  'Qatar': 40270721.0,
#  'Romania': 28520802.0,
#  'Russia': 18789191.0,
#  'Rwanda': 40445566.0,
#  'San Marino': 40449752.0,
#  'Saudi Arabia': 33746750.0,
#  'Senegal': 40183727.0,
#  'Serbia': 37222110.0,
#  'Seychelles': 40461653.0,
#  'Sierra Leone': 40442231.0,
#  'Singapore': 40459113.0,
#  'Slovak Republic': 38658564.0,
#  'Slovenia': 37722786.0,
#  'Solomon Islands': 40462968.0,
#  'Somalia': 40396146.0,
#  'South Africa': 23324476.0,
#  'South Korea': 39912831.0,
#  'South Sudan': 40446396.0,
#  'Spain': 19422762.0,
#  'Sri Lanka': 40370560.0,
#  'Sudan': 38785718.0,
#  'Suriname': 40409482.0,
#  'Sweden': 31721649.0,
#  'Switzerland': 32887839.0,
#  'Syria': 40004608.0,
#  'Taiwan': 40460823.0,
#  'Tajikistan': 40433271.0,
#  'Tanzania': 40460037.0,
#  'Thailand': 40448545.0,
#  'Timor-Leste': 40462139.0,
#  'Togo': 40443310.0,
#  'Trinidad and Tobago': 40395425.0,
#  'Tunisia': 35728302.0,
#  'Turkey': 26828772.0,
#  'Uganda': 40289362.0,
#  'Ukraine': 27616011.0,
#  'United Arab Emirates': 40000079.0,
#  'United Kingdom': 15047244.0,
#  'United Kingdom / England': 17019753.0,
#  'United Kingdom / Northern Ireland': 39301927.0,
#  'United Kingdom / Scotland': 35577031.0,
#  'United Kingdom / Wales': 36621670.0,
#  'United States': 8793688.0,
#  'United States / Alabama': 35328724.0,
#  'United States / Alaska': 40326891.0,
#  'United States / Arizona': 31935521.0,
#  'United States / Arkansas': 36292115.0,
#  'United States / California': 24312485.0,
#  'United States / Colorado': 35529850.0,
#  'United States / Connecticut': 33842920.0,
#  'United States / Delaware': 39888103.0,
#  'United States / Florida': 24717654.0,
#  'United States / Georgia': 30630076.0,
#  'United States / Hawaii': 40260760.0,
#  'United States / Idaho': 39101003.0,
#  'United States / Illinois': 28097553.0,
#  'United States / Indiana': 32221632.0,
#  'United States / Iowa': 36202065.0,
#  'United States / Kansas': 37482767.0,
#  'United States / Kentucky': 37618421.0,
#  'United States / Louisiana': 32432641.0,
#  'United States / Maine': 40247397.0,
#  'United States / Maryland': 33949848.0,
#  'United States / Massachusetts': 29773729.0,
#  'United States / Michigan': 29606062.0,
#  'United States / Minnesota': 34716312.0,
#  'United States / Mississippi': 35198350.0,
#  'United States / Missouri': 34369963.0,
#  'United States / Montana': 39862173.0,
#  'United States / Nebraska': 38744001.0,
#  'United States / Nevada': 36907438.0,
#  'United States / New Hampshire': 39939005.0,
#  'United States / New Jersey': 27024906.0,
#  'United States / New Mexico': 38092834.0,
#  'United States / New York': 20673441.0,
#  'United States / North Carolina': 33233197.0,
#  'United States / North Dakota': 39262343.0,
#  'United States / Ohio': 31478884.0,
#  'United States / Oklahoma': 38009258.0,
#  'United States / Oregon': 38959257.0,
#  'United States / Pennsylvania': 29192296.0,
#  'United States / Rhode Island': 38527218.0,
#  'United States / South Carolina': 34467673.0,
#  'United States / South Dakota': 38867776.0,
#  'United States / Tennessee': 33733228.0,
#  'United States / Texas': 22293157.0,
#  'United States / Utah': 39508085.0,
#  'United States / Vermont': 40417482.0,
#  'United States / Virginia': 35122504.0,
#  'United States / Washington': 36551135.0,
#  'United States / West Virginia': 39556539.0,
#  'United States / Wisconsin': 34969243.0,
#  'United States / Wyoming': 40216418.0,
#  'Uruguay': 40409109.0,
#  'Uzbekistan': 40013500.0,
#  'Vanuatu': 40461706.0,
#  'Venezuela': 39796051.0,
#  'Vietnam': 40458700.0,
#  'Yemen': 39939334.0,
#  'Zambia': 40181478.0,
#  'Zimbabwe': 40234823.0}

# %%
# TESTING AND PREDICTION ---
DATA_PATH = os.path.join("data", 'OxCGRT_latest_aug.csv')
model_weights_file = "models/trained_model_weights.h5"

import xprize_predictor
from importlib import reload
reload(xprize_predictor)

from xprize_predictor import XPrizePredictor

predictor = XPrizePredictor(model_weights_file, DATA_PATH)

NPIS_INPUT_FILE = "../../validation/data/2020-09-30_historical_ip.csv"
start_date = "2020-08-01"
end_date = "2020-08-31"
 
preds_df = predictor.predict(start_date, end_date, NPIS_INPUT_FILE)
preds_df.head()
# Out:
# Start and end date 2020-08-01 00:00:00 2020-08-31 00:00:00
# days 31
# Index(['CountryName', 'RegionName', 'Date', 'C1_School closing',
#        'C2_Workplace closing', 'C3_Cancel public events',
#        'C4_Restrictions on gatherings', 'C5_Close public transport',
#        'C6_Stay at home requirements', 'C7_Restrictions on internal movement',
#        'C8_International travel controls', 'H1_Public information campaigns',
#        'H2_Testing policy', 'H3_Contact tracing', 'H6_Facial Coverings',
#        'GeoID', 'Holidays', 'density_perkm2'],
#       dtype='object')
# Index(['CountryName', 'RegionName', 'Date', 'PredictedDailyNewCases'], dtype='object')
#   CountryName RegionName       Date  PredictedDailyNewCases
# 0       Aruba            2020-08-01                     0.0
# 1       Aruba            2020-08-02                     0.0
# 2       Aruba            2020-08-03                     0.0
# 3       Aruba            2020-08-04                     0.0
# 4       Aruba            2020-08-05                     0.0

# %%
preds_df.to_csv("a.csv")

# %%
# !python predict.py -s 2020-08-01 -e 2020-08-04 -ip ../../validation/data/2020-09-30_historical_ip.csv -o predictions/2020-08-01_2020-08-04.csv
# !head predictions/2020-08-01_2020-08-04.csv

# %%
# Check the pediction file is valid
import os
from covid_xprize.validation.predictor_validation import validate_submission

def validate(start_date, end_date, ip_file, output_file):
    # First, delete any potential old file
    try:
        os.remove(output_file)
    except OSError:
        pass
    
    # Then generate the prediction, calling the official API
    # !python predict.py -s {start_date} -e {end_date} -ip {ip_file} -o {output_file}
    
    # And validate it
    errors = validate_submission(start_date, end_date, ip_file, output_file)
    if errors:
        for error in errors:
            print(error)
    else:
        print("All good!")

# %%
validate(start_date="2020-08-01",
         end_date="2020-08-04",
         ip_file="../../validation/data/2020-09-30_historical_ip.csv",
         output_file="predictions/val_4_days.csv")

# %%
# %%time
validate(start_date="2021-01-01",
         end_date="2021-01-31",
         ip_file="../../validation/data/future_ip.csv",
         output_file="predictions/val_1_month_future.csv")

# %%
from datetime import datetime, timedelta

start_date = datetime.now() + timedelta(days=7)
start_date_str = start_date.strftime('%Y-%m-%d')
end_date = start_date + timedelta(days=180)
end_date_str = end_date.strftime('%Y-%m-%d')
print(f"Start date: {start_date_str}")
print(f"End date: {end_date_str}")

# %%
from covid_xprize.validation.scenario_generator import get_raw_data, generate_scenario, NPI_COLUMNS
DATA_FILE = 'data/OxCGRT_latest.csv'
latest_df = get_raw_data(DATA_FILE, latest=True)
scenario_df = generate_scenario(start_date_str, end_date_str, latest_df, countries=None, scenario="Freeze")
scenario_file = "predictions/180_days_future_scenario.csv"
scenario_df.to_csv(scenario_file, index=False)
print(f"Saved scenario to {scenario_file}")

# %%
# %%time
validate(start_date=start_date_str,
         end_date=end_date_str,
         ip_file=scenario_file,
         output_file="predictions/val_6_month_future.csv")

# %%
#TESTING/DEBUGGING CODE
import pandas as pd
from util import add_features_df

df = pd.read_csv("../../validation/data/2020-09-30_historical_ip.csv",
                                parse_dates=['Date'],
                                encoding="ISO-8859-1",) 
df["RegionName"] = df["RegionName"].fillna(value="") 
add_features_df(df)
